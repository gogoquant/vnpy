# %%
import sys
import pdb
from time import sleep
from logging import INFO
from vnpy.trader.setting import SETTINGS
from vnpy.trader.constant import Exchange
from vnpy.app.script_trader import init_cli_trading
from vnpy.gateway.huobif import HuobifGateway
from time import sleep
from easydl import clear_output

SETTINGS["log.active"] = True
SETTINGS["log.level"] = INFO
SETTINGS["log.console"] = True

Exchange = 'HUOBIF'
    
default_setting = {
    "API Key": "2be6e594-12edb3eb-rfhfg2mkl3-74a68",
    "Secret Key": "f3084214-4652d4fd-882f8eb2-b0256",
    "会话数": 3,
    "代理地址": "127.0.0.1",
    "代理端口": "1087",
 
}


engine = init_cli_trading([HuobifGateway])
engine.connect_gateway(default_setting, Exchange)
print('准备交易')
# 订阅行情
sleep(15)
print('开始交易')
# Out:
# 2021-05-14 10:17:29,153  INFO: REST API启动成功
# 2021-05-14 10:17:29,209  INFO: 触发异常，状态码：<class 'requests.exceptions.ProxyError'>，信息：HTTPSConnectionPool(host='api.hbdm.com', port=443): Max retries exceeded with url: /api/v1/contract_contract_info?AccessKeyId=2be6e594-12edb3eb-rfhfg2mkl3-74a68&SignatureMethod=HmacSHA256&SignatureVersion=2&Timestamp=2021-05-14T02%3A17%3A29&Signature=2yKxCNfFhDf%2FVMsG9K48EmBpCq0TpQF%2FFITtIO95aNY%3D (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x12b5698e0>: Failed to establish a new connection: [Errno 61] Connection refused')))
# [easydl] tensorflow not available!
# 2021-05-14 10:17:29.141969	REST API启动成功
# 准备交易
# 2021-05-14 10:17:29.195413	触发异常，状态码：<class 'requests.exceptions.ProxyError'>，信息：HTTPSConnectionPool(host='api.hbdm.com', port=443): Max retries exceeded with url: /api/v1/contract_contract_info?AccessKeyId=2be6e594-12edb3eb-rfhfg2mkl3-74a68&SignatureMethod=HmacSHA256&SignatureVersion=2&Timestamp=2021-05-14T02%3A17%3A29&Signature=2yKxCNfFhDf%2FVMsG9K48EmBpCq0TpQF%2FFITtIO95aNY%3D (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x12b5698e0>: Failed to establish a new connection: [Errno 61] Connection refused')))
# [2021-05-14T10:17:29.196036]: Unhandled RestClient Error:<class 'requests.exceptions.ProxyError'>
# request:request : GET /api/v1/contract_contract_info error because terminated:
# headers: {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.71 Safari/537.36'}
# params: {'AccessKeyId': '2be6e594-12edb3eb-rfhfg2mkl3-74a68', 'SignatureMethod': 'HmacSHA256', 'SignatureVersion': '2', 'Timestamp': '2021-05-14T02:17:29', 'Signature': '2yKxCNfFhDf/VMsG9K48EmBpCq0TpQF/FITtIO95aNY='}
# data: None
# response:
#
# Exception trace:
# Traceback (most recent call last):
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/urllib3/connection.py", line 169, in _new_conn
#     conn = connection.create_connection(
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/urllib3/util/connection.py", line 96, in create_connection
#     raise err
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/urllib3/util/connection.py", line 86, in create_connection
#     sock.connect(sa)
# ConnectionRefusedError: [Errno 61] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py", line 696, in urlopen
#     self._prepare_proxy(conn)
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py", line 964, in _prepare_proxy
#     conn.connect()
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/urllib3/connection.py", line 353, in connect
#     conn = self._new_conn()
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/urllib3/connection.py", line 181, in _new_conn
#     raise NewConnectionError(
# urllib3.exceptions.NewConnectionError: <urllib3.connection.HTTPSConnection object at 0x12b5698e0>: Failed to establish a new connection: [Errno 61] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/requests/adapters.py", line 439, in send
#     resp = conn.urlopen(
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py", line 755, in urlopen
#     retries = retries.increment(
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/urllib3/util/retry.py", line 574, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='api.hbdm.com', port=443): Max retries exceeded with url: /api/v1/contract_contract_info?AccessKeyId=2be6e594-12edb3eb-rfhfg2mkl3-74a68&SignatureMethod=HmacSHA256&SignatureVersion=2&Timestamp=2021-05-14T02%3A17%3A29&Signature=2yKxCNfFhDf%2FVMsG9K48EmBpCq0TpQF%2FFITtIO95aNY%3D (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x12b5698e0>: Failed to establish a new connection: [Errno 61] Connection refused')))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/vnpy/api/rest/rest_client.py", line 256, in _process_request
#     response = session.request(
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/requests/sessions.py", line 542, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/requests/sessions.py", line 655, in send
#     r = adapter.send(request, **kwargs)
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/requests/adapters.py", line 510, in send
#     raise ProxyError(e, request=request)
# requests.exceptions.ProxyError: HTTPSConnectionPool(host='api.hbdm.com', port=443): Max retries exceeded with url: /api/v1/contract_contract_info?AccessKeyId=2be6e594-12edb3eb-rfhfg2mkl3-74a68&SignatureMethod=HmacSHA256&SignatureVersion=2&Timestamp=2021-05-14T02%3A17%3A29&Signature=2yKxCNfFhDf%2FVMsG9K48EmBpCq0TpQF%2FFITtIO95aNY%3D (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x12b5698e0>: Failed to establish a new connection: [Errno 61] Connection refused')))
# 2021-05-14 10:17:32,630  INFO: 触发异常，状态码：<class 'requests.exceptions.ProxyError'>，信息：HTTPSConnectionPool(host='api.hbdm.com', port=443): Max retries exceeded with url: /api/v1/contract_account_info?AccessKeyId=2be6e594-12edb3eb-rfhfg2mkl3-74a68&SignatureMethod=HmacSHA256&SignatureVersion=2&Timestamp=2021-05-14T02%3A17%3A32&Signature=ltWhHvmU12s%2F6A%2Bbpqra%2BbVX6JmAsnkIZsE%2BdvItAfM%3D (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x12b58a490>: Failed to establish a new connection: [Errno 61] Connection refused')))
# [2021-05-14T10:17:32.630094]: Unhandled RestClient Error:<class 'requests.exceptions.ProxyError'>
# request:request : POST /api/v1/contract_account_info error because terminated:
# headers: {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.71 Safari/537.36', 'Content-Type': 'application/json'}
# params: {'AccessKeyId': '2be6e594-12edb3eb-rfhfg2mkl3-74a68', 'SignatureMethod': 'HmacSHA256', 'SignatureVersion': '2', 'Timestamp': '2021-05-14T02:17:32', 'Signature': 'ltWhHvmU12s/6A+bpqra+bVX6JmAsnkIZsE+dvItAfM='}
# data: None
# response:
#
# Exception trace:
# Traceback (most recent call last):
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/urllib3/connection.py", line 169, in _new_conn
#     conn = connection.create_connection(
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/urllib3/util/connection.py", line 96, in create_connection
#     raise err
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/urllib3/util/connection.py", line 86, in create_connection
#     sock.connect(sa)
# ConnectionRefusedError: [Errno 61] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py", line 696, in urlopen
#     self._prepare_proxy(conn)
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py", line 964, in _prepare_proxy
#     conn.connect()
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/urllib3/connection.py", line 353, in connect
#     conn = self._new_conn()
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/urllib3/connection.py", line 181, in _new_conn
#     raise NewConnectionError(
# urllib3.exceptions.NewConnectionError: <urllib3.connection.HTTPSConnection object at 0x12b58a490>: Failed to establish a new connection: [Errno 61] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/requests/adapters.py", line 439, in send
#     resp = conn.urlopen(
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py", line 755, in urlopen
#     retries = retries.increment(
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/urllib3/util/retry.py", line 574, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='api.hbdm.com', port=443): Max retries exceeded with url: /api/v1/contract_account_info?AccessKeyId=2be6e594-12edb3eb-rfhfg2mkl3-74a68&SignatureMethod=HmacSHA256&SignatureVersion=2&Timestamp=2021-05-14T02%3A17%3A32&Signature=ltWhHvmU12s%2F6A%2Bbpqra%2BbVX6JmAsnkIZsE%2BdvItAfM%3D (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x12b58a490>: Failed to establish a new connection: [Errno 61] Connection refused')))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/vnpy/api/rest/rest_client.py", line 256, in _process_request
#     response = session.request(
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/requests/sessions.py", line 542, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/requests/sessions.py", line 655, in send
#     r = adapter.send(request, **kwargs)
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/requests/adapters.py", line 510, in send
#     raise ProxyError(e, request=request)
# requests.exceptions.ProxyError: HTTPSConnectionPool(host='api.hbdm.com', port=443): Max retries exceeded with url: /api/v1/contract_account_info?AccessKeyId=2be6e594-12edb3eb-rfhfg2mkl3-74a68&SignatureMethod=HmacSHA256&SignatureVersion=2&Timestamp=2021-05-14T02%3A17%3A32&Signature=ltWhHvmU12s%2F6A%2Bbpqra%2BbVX6JmAsnkIZsE%2BdvItAfM%3D (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x12b58a490>: Failed to establish a new connection: [Errno 61] Connection refused')))
# [2021-05-14T10:17:32.642712]: Unhandled RestClient Error:<class 'requests.exceptions.ProxyError'>
# request:request : POST /api/v1/contract_position_info error because terminated:
# headers: {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.71 Safari/537.36', 'Content-Type': 'application/json'}
# params: {'AccessKeyId': '2be6e594-12edb3eb-rfhfg2mkl3-74a68', 'SignatureMethod': 'HmacSHA256', 'SignatureVersion': '2', 'Timestamp': '2021-05-14T02:17:32', 'Signature': '03MCgvGqaNhIcC5+UKzJAGJa4wEKPP+1xVRsrwcA0TU='}
# data: None
# response:
#
# Exception trace:
# Traceback (most recent call last):
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/urllib3/connection.py", line 169, in _new_conn
#     conn = connection.create_connection(
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/urllib3/util/connection.py", line 96, in create_connection
#     raise err
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/urllib3/util/connection.py", line 86, in create_connection
#     sock.connect(sa)
# ConnectionRefusedError: [Errno 61] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py", line 696, in urlopen
#     self._prepare_proxy(conn)
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py", line 964, in _prepare_proxy
#     conn.connect()
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/urllib3/connection.py", line 353, in connect
#     conn = self._new_conn()
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/urllib3/connection.py", line 181, in _new_conn
#     raise NewConnectionError(
# urllib3.exceptions.NewConnectionError: <urllib3.connection.HTTPSConnection object at 0x12b55ca90>: Failed to establish a new connection: [Errno 61] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/requests/adapters.py", line 439, in send
#     resp = conn.urlopen(
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py", line 755, in urlopen
#     retries = retries.increment(
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/urllib3/util/retry.py", line 574, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='api.hbdm.com', port=443): Max retries exceeded with url: /api/v1/contract_position_info?AccessKeyId=2be6e594-12edb3eb-rfhfg2mkl3-74a68&SignatureMethod=HmacSHA256&SignatureVersion=2&Timestamp=2021-05-14T02%3A17%3A32&Signature=03MCgvGqaNhIcC5%2BUKzJAGJa4wEKPP%2B1xVRsrwcA0TU%3D (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x12b55ca90>: Failed to establish a new connection: [Errno 61] Connection refused')))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/vnpy/api/rest/rest_client.py", line 256, in _process_request
#     response = session.request(
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/requests/sessions.py", line 542, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/requests/sessions.py", line 655, in send
#     r = adapter.send(request, **kwargs)
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/requests/adapters.py", line 510, in send
#     raise ProxyError(e, request=request)
# requests.exceptions.ProxyError: HTTPSConnectionPool(host='api.hbdm.com', port=443): Max retries exceeded with url: /api/v1/contract_position_info?AccessKeyId=2be6e594-12edb3eb-rfhfg2mkl3-74a68&SignatureMethod=HmacSHA256&SignatureVersion=2&Timestamp=2021-05-14T02%3A17%3A32&Signature=03MCgvGqaNhIcC5%2BUKzJAGJa4wEKPP%2B1xVRsrwcA0TU%3D (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x12b55ca90>: Failed to establish a new connection: [Errno 61] Connection refused')))
# 2021-05-14 10:17:32,647  INFO: 触发异常，状态码：<class 'requests.exceptions.ProxyError'>，信息：HTTPSConnectionPool(host='api.hbdm.com', port=443): Max retries exceeded with url: /api/v1/contract_position_info?AccessKeyId=2be6e594-12edb3eb-rfhfg2mkl3-74a68&SignatureMethod=HmacSHA256&SignatureVersion=2&Timestamp=2021-05-14T02%3A17%3A32&Signature=03MCgvGqaNhIcC5%2BUKzJAGJa4wEKPP%2B1xVRsrwcA0TU%3D (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x12b55ca90>: Failed to establish a new connection: [Errno 61] Connection refused')))
# 2021-05-14 10:17:32.630025	触发异常，状态码：<class 'requests.exceptions.ProxyError'>，信息：HTTPSConnectionPool(host='api.hbdm.com', port=443): Max retries exceeded with url: /api/v1/contract_account_info?AccessKeyId=2be6e594-12edb3eb-rfhfg2mkl3-74a68&SignatureMethod=HmacSHA256&SignatureVersion=2&Timestamp=2021-05-14T02%3A17%3A32&Signature=ltWhHvmU12s%2F6A%2Bbpqra%2BbVX6JmAsnkIZsE%2BdvItAfM%3D (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x12b58a490>: Failed to establish a new connection: [Errno 61] Connection refused')))
# 2021-05-14 10:17:32.642652	触发异常，状态码：<class 'requests.exceptions.ProxyError'>，信息：HTTPSConnectionPool(host='api.hbdm.com', port=443): Max retries exceeded with url: /api/v1/contract_position_info?AccessKeyId=2be6e594-12edb3eb-rfhfg2mkl3-74a68&SignatureMethod=HmacSHA256&SignatureVersion=2&Timestamp=2021-05-14T02%3A17%3A32&Signature=03MCgvGqaNhIcC5%2BUKzJAGJa4wEKPP%2B1xVRsrwcA0TU%3D (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x12b55ca90>: Failed to establish a new connection: [Errno 61] Connection refused')))
# 2021-05-14 10:17:33,125  INFO: 触发异常，状态码：<class 'requests.exceptions.ProxyError'>，信息：HTTPSConnectionPool(host='api.hbdm.com', port=443): Max retries exceeded with url: /api/v1/contract_account_info?AccessKeyId=2be6e594-12edb3eb-rfhfg2mkl3-74a68&SignatureMethod=HmacSHA256&SignatureVersion=2&Timestamp=2021-05-14T02%3A17%3A33&Signature=DbNXJHGTFFxTa6vSPsXBnie9NCD08CsubJMGyuhDMMU%3D (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x12b55c6a0>: Failed to establish a new connection: [Errno 61] Connection refused')))
# [2021-05-14T10:17:33.125171]: Unhandled RestClient Error:<class 'requests.exceptions.ProxyError'>
# request:request : POST /api/v1/contract_account_info error because terminated:
# headers: {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.71 Safari/537.36', 'Content-Type': 'application/json'}
# params: {'AccessKeyId': '2be6e594-12edb3eb-rfhfg2mkl3-74a68', 'SignatureMethod': 'HmacSHA256', 'SignatureVersion': '2', 'Timestamp': '2021-05-14T02:17:33', 'Signature': 'DbNXJHGTFFxTa6vSPsXBnie9NCD08CsubJMGyuhDMMU='}
# data: None
# response:
#
# Exception trace:
# Traceback (most recent call last):
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/urllib3/connection.py", line 169, in _new_conn
#     conn = connection.create_connection(
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/urllib3/util/connection.py", line 96, in create_connection
#     raise err
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/urllib3/util/connection.py", line 86, in create_connection
#     sock.connect(sa)
# ConnectionRefusedError: [Errno 61] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py", line 696, in urlopen
#     self._prepare_proxy(conn)
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py", line 964, in _prepare_proxy
#     conn.connect()
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/urllib3/connection.py", line 353, in connect
#     conn = self._new_conn()
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/urllib3/connection.py", line 181, in _new_conn
#     raise NewConnectionError(
# urllib3.exceptions.NewConnectionError: <urllib3.connection.HTTPSConnection object at 0x12b55c6a0>: Failed to establish a new connection: [Errno 61] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/requests/adapters.py", line 439, in send
#     resp = conn.urlopen(
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py", line 755, in urlopen
#     retries = retries.increment(
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/urllib3/util/retry.py", line 574, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='api.hbdm.com', port=443): Max retries exceeded with url: /api/v1/contract_account_info?AccessKeyId=2be6e594-12edb3eb-rfhfg2mkl3-74a68&SignatureMethod=HmacSHA256&SignatureVersion=2&Timestamp=2021-05-14T02%3A17%3A33&Signature=DbNXJHGTFFxTa6vSPsXBnie9NCD08CsubJMGyuhDMMU%3D (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x12b55c6a0>: Failed to establish a new connection: [Errno 61] Connection refused')))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/vnpy/api/rest/rest_client.py", line 256, in _process_request
#     response = session.request(
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/requests/sessions.py", line 542, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/requests/sessions.py", line 655, in send
#     r = adapter.send(request, **kwargs)
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/requests/adapters.py", line 510, in send
#     raise ProxyError(e, request=request)
# requests.exceptions.ProxyError: HTTPSConnectionPool(host='api.hbdm.com', port=443): Max retries exceeded with url: /api/v1/contract_account_info?AccessKeyId=2be6e594-12edb3eb-rfhfg2mkl3-74a68&SignatureMethod=HmacSHA256&SignatureVersion=2&Timestamp=2021-05-14T02%3A17%3A33&Signature=DbNXJHGTFFxTa6vSPsXBnie9NCD08CsubJMGyuhDMMU%3D (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x12b55c6a0>: Failed to establish a new connection: [Errno 61] Connection refused')))
# 2021-05-14 10:17:33,134  INFO: 触发异常，状态码：<class 'requests.exceptions.ProxyError'>，信息：HTTPSConnectionPool(host='api.hbdm.com', port=443): Max retries exceeded with url: /api/v1/contract_position_info?AccessKeyId=2be6e594-12edb3eb-rfhfg2mkl3-74a68&SignatureMethod=HmacSHA256&SignatureVersion=2&Timestamp=2021-05-14T02%3A17%3A33&Signature=49XYfoB5A%2FGjR%2BW4AJnqTq46e8wly0p%2Bur0%2FdWJE4ik%3D (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x12b55c940>: Failed to establish a new connection: [Errno 61] Connection refused')))
# 2021-05-14 10:17:33.125128	触发异常，状态码：<class 'requests.exceptions.ProxyError'>，信息：HTTPSConnectionPool(host='api.hbdm.com', port=443): Max retries exceeded with url: /api/v1/contract_account_info?AccessKeyId=2be6e594-12edb3eb-rfhfg2mkl3-74a68&SignatureMethod=HmacSHA256&SignatureVersion=2&Timestamp=2021-05-14T02%3A17%3A33&Signature=DbNXJHGTFFxTa6vSPsXBnie9NCD08CsubJMGyuhDMMU%3D (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x12b55c6a0>: Failed to establish a new connection: [Errno 61] Connection refused')))
# 2021-05-14 10:17:33.134395	触发异常，状态码：<class 'requests.exceptions.ProxyError'>，信息：HTTPSConnectionPool(host='api.hbdm.com', port=443): Max retries exceeded with url: /api/v1/contract_position_info?AccessKeyId=2be6e594-12edb3eb-rfhfg2mkl3-74a68&SignatureMethod=HmacSHA256&SignatureVersion=2&Timestamp=2021-05-14T02%3A17%3A33&Signature=49XYfoB5A%2FGjR%2BW4AJnqTq46e8wly0p%2Bur0%2FdWJE4ik%3D (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x12b55c940>: Failed to establish a new connection: [Errno 61] Connection refused')))
# [2021-05-14T10:17:33.134446]: Unhandled RestClient Error:<class 'requests.exceptions.ProxyError'>
# request:request : POST /api/v1/contract_position_info error because terminated:
# headers: {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.71 Safari/537.36', 'Content-Type': 'application/json'}
# params: {'AccessKeyId': '2be6e594-12edb3eb-rfhfg2mkl3-74a68', 'SignatureMethod': 'HmacSHA256', 'SignatureVersion': '2', 'Timestamp': '2021-05-14T02:17:33', 'Signature': '49XYfoB5A/GjR+W4AJnqTq46e8wly0p+ur0/dWJE4ik='}
# data: None
# response:
#
# Exception trace:
# Traceback (most recent call last):
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/urllib3/connection.py", line 169, in _new_conn
#     conn = connection.create_connection(
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/urllib3/util/connection.py", line 96, in create_connection
#     raise err
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/urllib3/util/connection.py", line 86, in create_connection
#     sock.connect(sa)
# ConnectionRefusedError: [Errno 61] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py", line 696, in urlopen
#     self._prepare_proxy(conn)
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py", line 964, in _prepare_proxy
#     conn.connect()
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/urllib3/connection.py", line 353, in connect
#     conn = self._new_conn()
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/urllib3/connection.py", line 181, in _new_conn
#     raise NewConnectionError(
# urllib3.exceptions.NewConnectionError: <urllib3.connection.HTTPSConnection object at 0x12b55c940>: Failed to establish a new connection: [Errno 61] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/requests/adapters.py", line 439, in send
#     resp = conn.urlopen(
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py", line 755, in urlopen
#     retries = retries.increment(
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/urllib3/util/retry.py", line 574, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='api.hbdm.com', port=443): Max retries exceeded with url: /api/v1/contract_position_info?AccessKeyId=2be6e594-12edb3eb-rfhfg2mkl3-74a68&SignatureMethod=HmacSHA256&SignatureVersion=2&Timestamp=2021-05-14T02%3A17%3A33&Signature=49XYfoB5A%2FGjR%2BW4AJnqTq46e8wly0p%2Bur0%2FdWJE4ik%3D (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x12b55c940>: Failed to establish a new connection: [Errno 61] Connection refused')))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/vnpy/api/rest/rest_client.py", line 256, in _process_request
#     response = session.request(
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/requests/sessions.py", line 542, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/requests/sessions.py", line 655, in send
#     r = adapter.send(request, **kwargs)
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/requests/adapters.py", line 510, in send
#     raise ProxyError(e, request=request)
# requests.exceptions.ProxyError: HTTPSConnectionPool(host='api.hbdm.com', port=443): Max retries exceeded with url: /api/v1/contract_position_info?AccessKeyId=2be6e594-12edb3eb-rfhfg2mkl3-74a68&SignatureMethod=HmacSHA256&SignatureVersion=2&Timestamp=2021-05-14T02%3A17%3A33&Signature=49XYfoB5A%2FGjR%2BW4AJnqTq46e8wly0p%2Bur0%2FdWJE4ik%3D (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x12b55c940>: Failed to establish a new connection: [Errno 61] Connection refused')))
# 2021-05-14 10:17:34,135  INFO: 触发异常，状态码：<class 'requests.exceptions.ProxyError'>，信息：HTTPSConnectionPool(host='api.hbdm.com', port=443): Max retries exceeded with url: /api/v1/contract_account_info?AccessKeyId=2be6e594-12edb3eb-rfhfg2mkl3-74a68&SignatureMethod=HmacSHA256&SignatureVersion=2&Timestamp=2021-05-14T02%3A17%3A34&Signature=7rsk9Xh%2F3aJdRaBz3FKewYlUdIqYwA85Ij5vzRs%2F9dQ%3D (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x12b54e0d0>: Failed to establish a new connection: [Errno 61] Connection refused')))
# [2021-05-14T10:17:34.133338]: Unhandled RestClient Error:<class 'requests.exceptions.ProxyError'>
# request:request : POST /api/v1/contract_account_info error because terminated:
# headers: {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.71 Safari/537.36', 'Content-Type': 'application/json'}
# params: {'AccessKeyId': '2be6e594-12edb3eb-rfhfg2mkl3-74a68', 'SignatureMethod': 'HmacSHA256', 'SignatureVersion': '2', 'Timestamp': '2021-05-14T02:17:34', 'Signature': '7rsk9Xh/3aJdRaBz3FKewYlUdIqYwA85Ij5vzRs/9dQ='}
# data: None
# response:
#
# Exception trace:
# Traceback (most recent call last):
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/urllib3/connection.py", line 169, in _new_conn
#     conn = connection.create_connection(
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/urllib3/util/connection.py", line 96, in create_connection
#     raise err
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/urllib3/util/connection.py", line 86, in create_connection
#     sock.connect(sa)
# ConnectionRefusedError: [Errno 61] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py", line 696, in urlopen
#     self._prepare_proxy(conn)
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py", line 964, in _prepare_proxy
#     conn.connect()
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/urllib3/connection.py", line 353, in connect
#     conn = self._new_conn()
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/urllib3/connection.py", line 181, in _new_conn
#     raise NewConnectionError(
# urllib3.exceptions.NewConnectionError: <urllib3.connection.HTTPSConnection object at 0x12b54e0d0>: Failed to establish a new connection: [Errno 61] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/requests/adapters.py", line 439, in send
#     resp = conn.urlopen(
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py", line 755, in urlopen
#     retries = retries.increment(
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/urllib3/util/retry.py", line 574, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='api.hbdm.com', port=443): Max retries exceeded with url: /api/v1/contract_account_info?AccessKeyId=2be6e594-12edb3eb-rfhfg2mkl3-74a68&SignatureMethod=HmacSHA256&SignatureVersion=2&Timestamp=2021-05-14T02%3A17%3A34&Signature=7rsk9Xh%2F3aJdRaBz3FKewYlUdIqYwA85Ij5vzRs%2F9dQ%3D (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x12b54e0d0>: Failed to establish a new connection: [Errno 61] Connection refused')))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/vnpy/api/rest/rest_client.py", line 256, in _process_request
#     response = session.request(
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/requests/sessions.py", line 542, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/requests/sessions.py", line 655, in send
#     r = adapter.send(request, **kwargs)
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/requests/adapters.py", line 510, in send
#     raise ProxyError(e, request=request)
# requests.exceptions.ProxyError: HTTPSConnectionPool(host='api.hbdm.com', port=443): Max retries exceeded with url: /api/v1/contract_account_info?AccessKeyId=2be6e594-12edb3eb-rfhfg2mkl3-74a68&SignatureMethod=HmacSHA256&SignatureVersion=2&Timestamp=2021-05-14T02%3A17%3A34&Signature=7rsk9Xh%2F3aJdRaBz3FKewYlUdIqYwA85Ij5vzRs%2F9dQ%3D (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x12b54e0d0>: Failed to establish a new connection: [Errno 61] Connection refused')))
# [2021-05-14T10:17:34.157957]: Unhandled RestClient Error:<class 'requests.exceptions.ProxyError'>
# request:request : POST /api/v1/contract_position_info error because terminated:
# headers: {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.71 Safari/537.36', 'Content-Type': 'application/json'}
# params: {'AccessKeyId': '2be6e594-12edb3eb-rfhfg2mkl3-74a68', 'SignatureMethod': 'HmacSHA256', 'SignatureVersion': '2', 'Timestamp': '2021-05-14T02:17:34', 'Signature': 'fMUkYFj+Twm5znuhq8lNxKqG25/hDAdih++ETsrnAj8='}
# data: None
# response:
#
# Exception trace:
# Traceback (most recent call last):
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/urllib3/connection.py", line 169, in _new_conn
#     conn = connection.create_connection(
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/urllib3/util/connection.py", line 96, in create_connection
#     raise err
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/urllib3/util/connection.py", line 86, in create_connection
#     sock.connect(sa)
# ConnectionRefusedError: [Errno 61] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py", line 696, in urlopen
#     self._prepare_proxy(conn)
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py", line 964, in _prepare_proxy
#     conn.connect()
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/urllib3/connection.py", line 353, in connect
#     conn = self._new_conn()
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/urllib3/connection.py", line 181, in _new_conn
#     raise NewConnectionError(
# urllib3.exceptions.NewConnectionError: <urllib3.connection.HTTPSConnection object at 0x12b54ed90>: Failed to establish a new connection: [Errno 61] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/requests/adapters.py", line 439, in send
#     resp = conn.urlopen(
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py", line 755, in urlopen
#     retries = retries.increment(
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/urllib3/util/retry.py", line 574, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='api.hbdm.com', port=443): Max retries exceeded with url: /api/v1/contract_position_info?AccessKeyId=2be6e594-12edb3eb-rfhfg2mkl3-74a68&SignatureMethod=HmacSHA256&SignatureVersion=2&Timestamp=2021-05-14T02%3A17%3A34&Signature=fMUkYFj%2BTwm5znuhq8lNxKqG25%2FhDAdih%2B%2BETsrnAj8%3D (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x12b54ed90>: Failed to establish a new connection: [Errno 61] Connection refused')))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/vnpy/api/rest/rest_client.py", line 256, in _process_request
#     response = session.request(
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/requests/sessions.py", line 542, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/requests/sessions.py", line 655, in send
#     r = adapter.send(request, **kwargs)
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/requests/adapters.py", line 510, in send
#     raise ProxyError(e, request=request)
# requests.exceptions.ProxyError: HTTPSConnectionPool(host='api.hbdm.com', port=443): Max retries exceeded with url: /api/v1/contract_position_info?AccessKeyId=2be6e594-12edb3eb-rfhfg2mkl3-74a68&SignatureMethod=HmacSHA256&SignatureVersion=2&Timestamp=2021-05-14T02%3A17%3A34&Signature=fMUkYFj%2BTwm5znuhq8lNxKqG25%2FhDAdih%2B%2BETsrnAj8%3D (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x12b54ed90>: Failed to establish a new connection: [Errno 61] Connection refused')))
# 2021-05-14 10:17:34,163  INFO: 触发异常，状态码：<class 'requests.exceptions.ProxyError'>，信息：HTTPSConnectionPool(host='api.hbdm.com', port=443): Max retries exceeded with url: /api/v1/contract_position_info?AccessKeyId=2be6e594-12edb3eb-rfhfg2mkl3-74a68&SignatureMethod=HmacSHA256&SignatureVersion=2&Timestamp=2021-05-14T02%3A17%3A34&Signature=fMUkYFj%2BTwm5znuhq8lNxKqG25%2FhDAdih%2B%2BETsrnAj8%3D (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x12b54ed90>: Failed to establish a new connection: [Errno 61] Connection refused')))
# 2021-05-14 10:17:34.133265	触发异常，状态码：<class 'requests.exceptions.ProxyError'>，信息：HTTPSConnectionPool(host='api.hbdm.com', port=443): Max retries exceeded with url: /api/v1/contract_account_info?AccessKeyId=2be6e594-12edb3eb-rfhfg2mkl3-74a68&SignatureMethod=HmacSHA256&SignatureVersion=2&Timestamp=2021-05-14T02%3A17%3A34&Signature=7rsk9Xh%2F3aJdRaBz3FKewYlUdIqYwA85Ij5vzRs%2F9dQ%3D (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x12b54e0d0>: Failed to establish a new connection: [Errno 61] Connection refused')))
# 2021-05-14 10:17:34.157781	触发异常，状态码：<class 'requests.exceptions.ProxyError'>，信息：HTTPSConnectionPool(host='api.hbdm.com', port=443): Max retries exceeded with url: /api/v1/contract_position_info?AccessKeyId=2be6e594-12edb3eb-rfhfg2mkl3-74a68&SignatureMethod=HmacSHA256&SignatureVersion=2&Timestamp=2021-05-14T02%3A17%3A34&Signature=fMUkYFj%2BTwm5znuhq8lNxKqG25%2FhDAdih%2B%2BETsrnAj8%3D (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x12b54ed90>: Failed to establish a new connection: [Errno 61] Connection refused')))
# 2021-05-14 10:17:38,668  INFO: 触发异常，状态码：<class 'requests.exceptions.ProxyError'>，信息：HTTPSConnectionPool(host='api.hbdm.com', port=443): Max retries exceeded with url: /api/v1/contract_account_info?AccessKeyId=2be6e594-12edb3eb-rfhfg2mkl3-74a68&SignatureMethod=HmacSHA256&SignatureVersion=2&Timestamp=2021-05-14T02%3A17%3A35&Signature=CSTVX75%2BqXQFUPxTpSHmtDK4LdL4fvXfB19VovV0VPc%3D (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x12b541460>: Failed to establish a new connection: [Errno 61] Connection refused')))
# [2021-05-14T10:17:38.667552]: Unhandled RestClient Error:<class 'requests.exceptions.ProxyError'>
# request:request : POST /api/v1/contract_account_info error because terminated:
# headers: {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.71 Safari/537.36', 'Content-Type': 'application/json'}
# params: {'AccessKeyId': '2be6e594-12edb3eb-rfhfg2mkl3-74a68', 'SignatureMethod': 'HmacSHA256', 'SignatureVersion': '2', 'Timestamp': '2021-05-14T02:17:35', 'Signature': 'CSTVX75+qXQFUPxTpSHmtDK4LdL4fvXfB19VovV0VPc='}
# data: None
# response:
#
# Exception trace:
# Traceback (most recent call last):
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/urllib3/connection.py", line 169, in _new_conn
#     conn = connection.create_connection(
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/urllib3/util/connection.py", line 96, in create_connection
#     raise err
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/urllib3/util/connection.py", line 86, in create_connection
#     sock.connect(sa)
# ConnectionRefusedError: [Errno 61] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py", line 696, in urlopen
#     self._prepare_proxy(conn)
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py", line 964, in _prepare_proxy
#     conn.connect()
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/urllib3/connection.py", line 353, in connect
#     conn = self._new_conn()
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/urllib3/connection.py", line 181, in _new_conn
#     raise NewConnectionError(
# urllib3.exceptions.NewConnectionError: <urllib3.connection.HTTPSConnection object at 0x12b541460>: Failed to establish a new connection: [Errno 61] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/requests/adapters.py", line 439, in send
#     resp = conn.urlopen(
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py", line 755, in urlopen
#     retries = retries.increment(
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/urllib3/util/retry.py", line 574, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='api.hbdm.com', port=443): Max retries exceeded with url: /api/v1/contract_account_info?AccessKeyId=2be6e594-12edb3eb-rfhfg2mkl3-74a68&SignatureMethod=HmacSHA256&SignatureVersion=2&Timestamp=2021-05-14T02%3A17%3A35&Signature=CSTVX75%2BqXQFUPxTpSHmtDK4LdL4fvXfB19VovV0VPc%3D (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x12b541460>: Failed to establish a new connection: [Errno 61] Connection refused')))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/vnpy/api/rest/rest_client.py", line 256, in _process_request
#     response = session.request(
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/requests/sessions.py", line 542, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/requests/sessions.py", line 655, in send
#     r = adapter.send(request, **kwargs)
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/requests/adapters.py", line 510, in send
#     raise ProxyError(e, request=request)
# requests.exceptions.ProxyError: HTTPSConnectionPool(host='api.hbdm.com', port=443): Max retries exceeded with url: /api/v1/contract_account_info?AccessKeyId=2be6e594-12edb3eb-rfhfg2mkl3-74a68&SignatureMethod=HmacSHA256&SignatureVersion=2&Timestamp=2021-05-14T02%3A17%3A35&Signature=CSTVX75%2BqXQFUPxTpSHmtDK4LdL4fvXfB19VovV0VPc%3D (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x12b541460>: Failed to establish a new connection: [Errno 61] Connection refused')))
# [2021-05-14T10:17:38.681953]: Unhandled RestClient Error:<class 'requests.exceptions.ProxyError'>
# request:request : POST /api/v1/contract_position_info error because terminated:
# headers: {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.71 Safari/537.36', 'Content-Type': 'application/json'}
# params: {'AccessKeyId': '2be6e594-12edb3eb-rfhfg2mkl3-74a68', 'SignatureMethod': 'HmacSHA256', 'SignatureVersion': '2', 'Timestamp': '2021-05-14T02:17:38', 'Signature': 'WIN4KtazsePxxUjfw5eY65czLdqbdt7gaUprmaT/Xjo='}
# data: None
# response:
#
# Exception trace:
# Traceback (most recent call last):
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/urllib3/connection.py", line 169, in _new_conn
#     conn = connection.create_connection(
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/urllib3/util/connection.py", line 96, in create_connection
#     raise err
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/urllib3/util/connection.py", line 86, in create_connection
#     sock.connect(sa)
# ConnectionRefusedError: [Errno 61] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py", line 696, in urlopen
#     self._prepare_proxy(conn)
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py", line 964, in _prepare_proxy
#     conn.connect()
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/urllib3/connection.py", line 353, in connect
#     conn = self._new_conn()
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/urllib3/connection.py", line 181, in _new_conn
#     raise NewConnectionError(
# urllib3.exceptions.NewConnectionError: <urllib3.connection.HTTPSConnection object at 0x12b5ebac0>: Failed to establish a new connection: [Errno 61] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/requests/adapters.py", line 439, in send
#     resp = conn.urlopen(
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py", line 755, in urlopen
#     retries = retries.increment(
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/urllib3/util/retry.py", line 574, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='api.hbdm.com', port=443): Max retries exceeded with url: /api/v1/contract_position_info?AccessKeyId=2be6e594-12edb3eb-rfhfg2mkl3-74a68&SignatureMethod=HmacSHA256&SignatureVersion=2&Timestamp=2021-05-14T02%3A17%3A38&Signature=WIN4KtazsePxxUjfw5eY65czLdqbdt7gaUprmaT%2FXjo%3D (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x12b5ebac0>: Failed to establish a new connection: [Errno 61] Connection refused')))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/vnpy/api/rest/rest_client.py", line 256, in _process_request
#     response = session.request(
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/requests/sessions.py", line 542, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/requests/sessions.py", line 655, in send
#     r = adapter.send(request, **kwargs)
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/requests/adapters.py", line 510, in send
#     raise ProxyError(e, request=request)
# requests.exceptions.ProxyError: HTTPSConnectionPool(host='api.hbdm.com', port=443): Max retries exceeded with url: /api/v1/contract_position_info?AccessKeyId=2be6e594-12edb3eb-rfhfg2mkl3-74a68&SignatureMethod=HmacSHA256&SignatureVersion=2&Timestamp=2021-05-14T02%3A17%3A38&Signature=WIN4KtazsePxxUjfw5eY65czLdqbdt7gaUprmaT%2FXjo%3D (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x12b5ebac0>: Failed to establish a new connection: [Errno 61] Connection refused')))
# 2021-05-14 10:17:38,698  INFO: 触发异常，状态码：<class 'requests.exceptions.ProxyError'>，信息：HTTPSConnectionPool(host='api.hbdm.com', port=443): Max retries exceeded with url: /api/v1/contract_position_info?AccessKeyId=2be6e594-12edb3eb-rfhfg2mkl3-74a68&SignatureMethod=HmacSHA256&SignatureVersion=2&Timestamp=2021-05-14T02%3A17%3A38&Signature=WIN4KtazsePxxUjfw5eY65czLdqbdt7gaUprmaT%2FXjo%3D (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x12b5ebac0>: Failed to establish a new connection: [Errno 61] Connection refused')))
# ...
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/vnpy/api/rest/rest_client.py", line 256, in _process_request
#     response = session.request(
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/requests/sessions.py", line 542, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/requests/sessions.py", line 655, in send
#     r = adapter.send(request, **kwargs)
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/requests/adapters.py", line 510, in send
#     raise ProxyError(e, request=request)
# requests.exceptions.ProxyError: HTTPSConnectionPool(host='api.hbdm.com', port=443): Max retries exceeded with url: /api/v1/contract_position_info?AccessKeyId=2be6e594-12edb3eb-rfhfg2mkl3-74a68&SignatureMethod=HmacSHA256&SignatureVersion=2&Timestamp=2021-05-14T02%3A17%3A46&Signature=6oKNOxBGUDH57fcW3l8rqT5H4VyXdHF%2BZAOimf4YfKQ%3D (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x12b54e250>: Failed to establish a new connection: [Errno 61] Connection refused')))
# 2021-05-14 10:17:46,749  INFO: 触发异常，状态码：<class 'requests.exceptions.ProxyError'>，信息：HTTPSConnectionPool(host='api.hbdm.com', port=443): Max retries exceeded with url: /api/v1/contract_account_info?AccessKeyId=2be6e594-12edb3eb-rfhfg2mkl3-74a68&SignatureMethod=HmacSHA256&SignatureVersion=2&Timestamp=2021-05-14T02%3A17%3A46&Signature=niPPvG10Bjh11bRfaKqLL%2BX6i8NwMvyrIZ%2BFoE3vWR4%3D (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x12b54e3a0>: Failed to establish a new connection: [Errno 61] Connection refused')))
# [2021-05-14T10:17:46.749241]: Unhandled RestClient Error:<class 'requests.exceptions.ProxyError'>
# request:request : POST /api/v1/contract_account_info error because terminated:
# headers: {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.71 Safari/537.36', 'Content-Type': 'application/json'}
# params: {'AccessKeyId': '2be6e594-12edb3eb-rfhfg2mkl3-74a68', 'SignatureMethod': 'HmacSHA256', 'SignatureVersion': '2', 'Timestamp': '2021-05-14T02:17:46', 'Signature': 'niPPvG10Bjh11bRfaKqLL+X6i8NwMvyrIZ+FoE3vWR4='}
# data: None
# response:
#
# Exception trace:
# Traceback (most recent call last):
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/urllib3/connection.py", line 169, in _new_conn
#     conn = connection.create_connection(
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/urllib3/util/connection.py", line 96, in create_connection
#     raise err
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/urllib3/util/connection.py", line 86, in create_connection
#     sock.connect(sa)
# ConnectionRefusedError: [Errno 61] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py", line 696, in urlopen
#     self._prepare_proxy(conn)
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py", line 964, in _prepare_proxy
#     conn.connect()
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/urllib3/connection.py", line 353, in connect
#     conn = self._new_conn()
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/urllib3/connection.py", line 181, in _new_conn
#     raise NewConnectionError(
# urllib3.exceptions.NewConnectionError: <urllib3.connection.HTTPSConnection object at 0x12b54e3a0>: Failed to establish a new connection: [Errno 61] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/requests/adapters.py", line 439, in send
#     resp = conn.urlopen(
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py", line 755, in urlopen
#     retries = retries.increment(
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/urllib3/util/retry.py", line 574, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='api.hbdm.com', port=443): Max retries exceeded with url: /api/v1/contract_account_info?AccessKeyId=2be6e594-12edb3eb-rfhfg2mkl3-74a68&SignatureMethod=HmacSHA256&SignatureVersion=2&Timestamp=2021-05-14T02%3A17%3A46&Signature=niPPvG10Bjh11bRfaKqLL%2BX6i8NwMvyrIZ%2BFoE3vWR4%3D (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x12b54e3a0>: Failed to establish a new connection: [Errno 61] Connection refused')))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/vnpy/api/rest/rest_client.py", line 256, in _process_request
#     response = session.request(
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/requests/sessions.py", line 542, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/requests/sessions.py", line 655, in send
#     r = adapter.send(request, **kwargs)
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/requests/adapters.py", line 510, in send
#     raise ProxyError(e, request=request)
# requests.exceptions.ProxyError: HTTPSConnectionPool(host='api.hbdm.com', port=443): Max retries exceeded with url: /api/v1/contract_account_info?AccessKeyId=2be6e594-12edb3eb-rfhfg2mkl3-74a68&SignatureMethod=HmacSHA256&SignatureVersion=2&Timestamp=2021-05-14T02%3A17%3A46&Signature=niPPvG10Bjh11bRfaKqLL%2BX6i8NwMvyrIZ%2BFoE3vWR4%3D (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x12b54e3a0>: Failed to establish a new connection: [Errno 61] Connection refused')))
# 2021-05-14 10:17:46,757  INFO: 触发异常，状态码：<class 'requests.exceptions.ProxyError'>，信息：HTTPSConnectionPool(host='api.hbdm.com', port=443): Max retries exceeded with url: /api/v1/contract_position_info?AccessKeyId=2be6e594-12edb3eb-rfhfg2mkl3-74a68&SignatureMethod=HmacSHA256&SignatureVersion=2&Timestamp=2021-05-14T02%3A17%3A46&Signature=6oKNOxBGUDH57fcW3l8rqT5H4VyXdHF%2BZAOimf4YfKQ%3D (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x12b569c40>: Failed to establish a new connection: [Errno 61] Connection refused')))
# 2021-05-14 10:17:46.698737	触发异常，状态码：<class 'requests.exceptions.ProxyError'>，信息：HTTPSConnectionPool(host='api.hbdm.com', port=443): Max retries exceeded with url: /api/v1/contract_account_info?AccessKeyId=2be6e594-12edb3eb-rfhfg2mkl3-74a68&SignatureMethod=HmacSHA256&SignatureVersion=2&Timestamp=2021-05-14T02%3A17%3A43&Signature=vEFSoMHEKFDvR07GeDhePlLT7WqfhAhnKHwLmNho2EA%3D (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x12b58a520>: Failed to establish a new connection: [Errno 61] Connection refused')))
# 2021-05-14 10:17:46.706352	触发异常，状态码：<class 'requests.exceptions.ProxyError'>，信息：HTTPSConnectionPool(host='api.hbdm.com', port=443): Max retries exceeded with url: /api/v1/contract_position_info?AccessKeyId=2be6e594-12edb3eb-rfhfg2mkl3-74a68&SignatureMethod=HmacSHA256&SignatureVersion=2&Timestamp=2021-05-14T02%3A17%3A46&Signature=6oKNOxBGUDH57fcW3l8rqT5H4VyXdHF%2BZAOimf4YfKQ%3D (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x12b541340>: Failed to establish a new connection: [Errno 61] Connection refused')))
# 2021-05-14 10:17:46.716520	触发异常，状态码：<class 'requests.exceptions.ProxyError'>，信息：HTTPSConnectionPool(host='api.hbdm.com', port=443): Max retries exceeded with url: /api/v1/contract_account_info?AccessKeyId=2be6e594-12edb3eb-rfhfg2mkl3-74a68&SignatureMethod=HmacSHA256&SignatureVersion=2&Timestamp=2021-05-14T02%3A17%3A46&Signature=niPPvG10Bjh11bRfaKqLL%2BX6i8NwMvyrIZ%2BFoE3vWR4%3D (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x12b55c1f0>: Failed to establish a new connection: [Errno 61] Connection refused')))
# 2021-05-14 10:17:46.725316	触发异常，状态码：<class 'requests.exceptions.ProxyError'>，信息：HTTPSConnectionPool(host='api.hbdm.com', port=443): Max retries exceeded with url: /api/v1/contract_position_info?AccessKeyId=2be6e594-12edb3eb-rfhfg2mkl3-74a68&SignatureMethod=HmacSHA256&SignatureVersion=2&Timestamp=2021-05-14T02%3A17%3A46&Signature=6oKNOxBGUDH57fcW3l8rqT5H4VyXdHF%2BZAOimf4YfKQ%3D (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x12b55cac0>: Failed to establish a new connection: [Errno 61] Connection refused')))
# 2021-05-14 10:17:46.731879	触发异常，状态码：<class 'requests.exceptions.ProxyError'>，信息：HTTPSConnectionPool(host='api.hbdm.com', port=443): Max retries exceeded with url: /api/v1/contract_account_info?AccessKeyId=2be6e594-12edb3eb-rfhfg2mkl3-74a68&SignatureMethod=HmacSHA256&SignatureVersion=2&Timestamp=2021-05-14T02%3A17%3A46&Signature=niPPvG10Bjh11bRfaKqLL%2BX6i8NwMvyrIZ%2BFoE3vWR4%3D (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x12b55c2e0>: Failed to establish a new connection: [Errno 61] Connection refused')))
# 2021-05-14 10:17:46.738556	触发异常，状态码：<class 'requests.exceptions.ProxyError'>，信息：HTTPSConnectionPool(host='api.hbdm.com', port=443): Max retries exceeded with url: /api/v1/contract_position_info?AccessKeyId=2be6e594-12edb3eb-rfhfg2mkl3-74a68&SignatureMethod=HmacSHA256&SignatureVersion=2&Timestamp=2021-05-14T02%3A17%3A46&Signature=6oKNOxBGUDH57fcW3l8rqT5H4VyXdHF%2BZAOimf4YfKQ%3D (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x12b54e250>: Failed to establish a new connection: [Errno 61] Connection refused')))
# 2021-05-14 10:17:46.749201	触发异常，状态码：<class 'requests.exceptions.ProxyError'>，信息：HTTPSConnectionPool(host='api.hbdm.com', port=443): Max retries exceeded with url: /api/v1/contract_account_info?AccessKeyId=2be6e594-12edb3eb-rfhfg2mkl3-74a68&SignatureMethod=HmacSHA256&SignatureVersion=2&Timestamp=2021-05-14T02%3A17%3A46&Signature=niPPvG10Bjh11bRfaKqLL%2BX6i8NwMvyrIZ%2BFoE3vWR4%3D (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x12b54e3a0>: Failed to establish a new connection: [Errno 61] Connection refused')))
# 2021-05-14 10:17:46.757336	触发异常，状态码：<class 'requests.exceptions.ProxyError'>，信息：HTTPSConnectionPool(host='api.hbdm.com', port=443): Max retries exceeded with url: /api/v1/contract_position_info?AccessKeyId=2be6e594-12edb3eb-rfhfg2mkl3-74a68&SignatureMethod=HmacSHA256&SignatureVersion=2&Timestamp=2021-05-14T02%3A17%3A46&Signature=6oKNOxBGUDH57fcW3l8rqT5H4VyXdHF%2BZAOimf4YfKQ%3D (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x12b569c40>: Failed to establish a new connection: [Errno 61] Connection refused')))
# [2021-05-14T10:17:46.757377]: Unhandled RestClient Error:<class 'requests.exceptions.ProxyError'>
# request:request : POST /api/v1/contract_position_info error because terminated:
# headers: {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.71 Safari/537.36', 'Content-Type': 'application/json'}
# params: {'AccessKeyId': '2be6e594-12edb3eb-rfhfg2mkl3-74a68', 'SignatureMethod': 'HmacSHA256', 'SignatureVersion': '2', 'Timestamp': '2021-05-14T02:17:46', 'Signature': '6oKNOxBGUDH57fcW3l8rqT5H4VyXdHF+ZAOimf4YfKQ='}
# data: None
# response:
#
# Exception trace:
# Traceback (most recent call last):
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/urllib3/connection.py", line 169, in _new_conn
#     conn = connection.create_connection(
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/urllib3/util/connection.py", line 96, in create_connection
#     raise err
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/urllib3/util/connection.py", line 86, in create_connection
#     sock.connect(sa)
# ConnectionRefusedError: [Errno 61] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py", line 696, in urlopen
#     self._prepare_proxy(conn)
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py", line 964, in _prepare_proxy
#     conn.connect()
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/urllib3/connection.py", line 353, in connect
#     conn = self._new_conn()
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/urllib3/connection.py", line 181, in _new_conn
#     raise NewConnectionError(
# urllib3.exceptions.NewConnectionError: <urllib3.connection.HTTPSConnection object at 0x12b569c40>: Failed to establish a new connection: [Errno 61] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/requests/adapters.py", line 439, in send
#     resp = conn.urlopen(
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py", line 755, in urlopen
#     retries = retries.increment(
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/urllib3/util/retry.py", line 574, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='api.hbdm.com', port=443): Max retries exceeded with url: /api/v1/contract_position_info?AccessKeyId=2be6e594-12edb3eb-rfhfg2mkl3-74a68&SignatureMethod=HmacSHA256&SignatureVersion=2&Timestamp=2021-05-14T02%3A17%3A46&Signature=6oKNOxBGUDH57fcW3l8rqT5H4VyXdHF%2BZAOimf4YfKQ%3D (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x12b569c40>: Failed to establish a new connection: [Errno 61] Connection refused')))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/vnpy/api/rest/rest_client.py", line 256, in _process_request
#     response = session.request(
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/requests/sessions.py", line 542, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/requests/sessions.py", line 655, in send
#     r = adapter.send(request, **kwargs)
#   File "/Users/shu/opt/anaconda3/lib/python3.8/site-packages/requests/adapters.py", line 510, in send
#     raise ProxyError(e, request=request)
# requests.exceptions.ProxyError: HTTPSConnectionPool(host='api.hbdm.com', port=443): Max retries exceeded with url: /api/v1/contract_position_info?AccessKeyId=2be6e594-12edb3eb-rfhfg2mkl3-74a68&SignatureMethod=HmacSHA256&SignatureVersion=2&Timestamp=2021-05-14T02%3A17%3A46&Signature=6oKNOxBGUDH57fcW3l8rqT5H4VyXdHF%2BZAOimf4YfKQ%3D (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x12b569c40>: Failed to establish a new connection: [Errno 61] Connection refused')))
# 2021-05-14 10:17:49,675  INFO: 行情Websocket API连接成功
# 2021-05-14 10:17:49.675185	行情Websocket API连接成功
# 2021-05-14 10:17:49,937  INFO: 交易Websocket API连接成功
# 2021-05-14 10:17:49.909453	交易Websocket API连接成功
# 2021-05-14 10:17:50,289  INFO: 交易Websocket API登录成功
# 2021-05-14 10:17:50.289052	交易Websocket API登录成功

# %%
# engine.subscribe(["ETH210924.HUOBI"])
# 查询所有合约
engine.get_all_contracts(use_df=True)

# 查询活动委托
# print(engine.get_all_active_orders(use_df=True))
